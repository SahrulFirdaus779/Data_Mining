# %%
import pandas as pd
df1 = pd.read_csv('dataset_mhs2024.csv', sep = ',')
df2 = pd.read_csv('datatesting_mhs2024.csv', sep = ',')
df1.rename(columns={'Berat (Kg)':'Berat'}, inplace=True)
df1.rename(columns={'Tinggi (cm)':'Tinggi'}, inplace=True)
df1
# Out:
#            Timestamp                           Nama  Umur Jenis Kelamin  \
# 0   12/19/2024 13:11                          Pathi    19     Laki-laki
# 1   12/19/2024 13:11             Diah Ayu Puspasari    19     Perempuan
# 2   12/19/2024 13:11                 Sahrul Firdaus    20     Laki-laki
# 3   12/19/2024 13:12  Aulia Nisya Nur Rahma Safitri    19     Perempuan
# 4   12/19/2024 13:12         Muhammad Fauzan Adhima    20     Laki-laki
# 5   12/19/2024 13:12          Ainisa Dinda Iskandar    19     Perempuan
# 6   12/19/2024 13:12     Mohammad Ghifari Rizkullah    20     Laki-laki
# 7   12/19/2024 13:12          Muhamad Akbar Rabbani    19     Laki-laki
# 8   12/19/2024 13:13                   Indri Rachma    21     Perempuan
# 9   12/19/2024 13:13         Safira Innayah Azzahro    20     Perempuan
# 10  12/19/2024 13:13        Muhammad Virgi Zulfahmi    19     Laki-laki
# 11  12/19/2024 13:13                 Shiba Raihanah    20     Perempuan
# ...

# %%
df2.rename(columns={'Berat (Kg)':'Berat'}, inplace=True)
df2.rename(columns={'Tinggi (cm)':'Tinggi'}, inplace=True)
df2
# Out:
#           Timestamp                          Nama  Umur Jenis Kelamin  Berat  \
# 0  12/19/2024 13:14                   Eka Kartini    20     Perempuan     57
# 1  12/19/2024 13:14                     Nurhayati    20     Perempuan     47
# 2  12/19/2024 13:14  Sabrina Jasmine Rambu Diena     19     Perempuan     70
# 3  12/19/2024 13:14           Elyas Randi Renaldi    20     Laki-laki     41
# 4  12/19/2024 13:15  Leohafs Sri Indrapura R Zain    21     Laki-laki     60
#
#    Tinggi
# 0     168
# 1     150
# 2     157
# 3     169
# 4     167

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodel.api as sum

x = df[['Umur', 'Tinggi']].to_numpy()
y = df['Berat'].to_numpy()

x = sm.add_constant(x)
model_prediksi = sm.OLS(y,x).fit();
print(model_prediksi.summary())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 import statsmodel.api as sum
#
# ModuleNotFoundError: No module named 'matplotlib'
